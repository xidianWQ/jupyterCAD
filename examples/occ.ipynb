# %% [markdown]
# ### Create a shape from the Open Cascade Python API

# %%
from OCC.Core.BRepPrimAPI import BRepPrimAPI_MakeBox

from jupytercad import CadDocument

doc = CadDocument()

box_shape = BRepPrimAPI_MakeBox(10, 20, 30).Shape()

doc.add_occ_shape(box_shape)

doc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from OCC.Core.BRepPrimAPI import BRepPrimAPI_MakeBox
#       3 from jupytercad import CadDocument
#       5 doc = CadDocument()
#
# ModuleNotFoundError: No module named 'OCC'

# %%
from OCC.Extend.DataExchange import read_stl_file

wheel = read_stl_file("fan.stl")

from jupytercad import CadDocument

doc = CadDocument()

doc.add_occ_shape(wheel)

doc
